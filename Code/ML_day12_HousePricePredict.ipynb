# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
x1data = np.loadtxt("/Users/user/Downloads/train.csv", delimiter=',',dtype=np.int32, skiprows=1,usecols=5)
x2data = np.loadtxt("/Users/user/Downloads/train.csv", delimiter=',',dtype=np.int32, skiprows=1,usecols=[5,3,4,6,16])
x3data = np.loadtxt("/Users/user/Downloads/train.csv", delimiter=',',dtype=np.int32, skiprows=1,usecols=[5,3,4])
ydata = np.loadtxt("/Users/user/Downloads/train.csv",delimiter=',',dtype=np.int32, skiprows=1,usecols=2)

# %%
x1data
# Out:
# array([1180,  770, 1680, ..., 1530, 2310, 1020])

# %%
x1data.shape
# Out:
# (15035,)

# %%
x1data=x1data.reshape(-1,1)

# %%
x1data.shape
# Out:
# (15035, 1)

# %%
ydata.shape
# Out:
# (15035,)

# %%
ydata=ydata.reshape(-1,1)

# %%
ydata.shape
# Out:
# (15035, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x1data,ydata,test_size=0.2,random_state=42)

# %%
x1=tf.placeholder(tf.float32,shape=[None,1])
y1=tf.placeholder(tf.float32,shape=[None,1])
w1=tf.Variable(tf.random_normal([1,1]),name='weight1')
b1=tf.Variable(tf.random_normal([1]),name='bias')

# %%
hf=x1@w1+b1
cost=tf.reduce_mean(tf.square(hf-y1))
train=tf.train.GradientDescentOptimizer(1e-7).minimize(cost)

# %%
sess=tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(10001):
    cv,hv,_ = sess.run([cost,hf,train],
            feed_dict={x1:x1data,y1:ydata})
    if step%10==0:
        print("cost:",cv,"prediction:",hv)
# Out:
# cost: 430944680000.0 prediction: [[-253.24387]
#  [-165.73178]
#  [-359.96594]
#  ...
#  [-327.9493 ]
#  [-494.43573]
#  [-219.0928 ]]
# cost: 70229780000.0 prediction: [[310759.1 ]
#  [202783.03]
#  [442437.25]
#  ...
#  [402933.8 ]
#  [608351.6 ]
#  [268622.1 ]]
# cost: 70229780000.0 prediction: [[310759.12]
#  [202783.03]
#  [442437.25]
#  ...
#  [402933.8 ]
#  [608351.75]
#  [268622.1 ]]
# cost: 70229790000.0 prediction: [[310759.12]
#  [202783.02]
#  [442437.25]
#  ...
#  [402933.8 ]
#  [608351.75]
#  [268622.1 ]]
# cost: 70229790000.0 prediction: [[310759.1 ]
#  [202783.  ]
#  [442437.22]
#  ...
#  [402933.78]
#  [608351.75]
#  [268622.06]]
# cost: 70229780000.0 prediction: [[310759.1 ]
#  [202782.98]
#  [442437.22]
#  ...
#  [402933.78]
#  [608351.7 ]
#  [268622.06]]
# cost: 70229780000.0 prediction: [[310759.06]
#  [202782.97]
#  [442437.2 ]
#  ...
#  [402933.75]
#  [608351.7 ]
#  [268622.03]]
# cost: 70229780000.0 prediction: [[310759.06]
#  [202782.95]
#  [442437.2 ]
# ...
