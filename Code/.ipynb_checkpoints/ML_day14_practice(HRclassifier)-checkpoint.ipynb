# %% [markdown]
# # HR 데이터를 기반으로 타깃(left)을 예상할 수 있는 분류 모델기 생성

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pylab as plt
import matplotlib as mlt

# %%
df=pd.read_csv("/Users/user/Downloads/HR_comma_sep.csv")
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
correlation=df.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlation,cmap='cubehelix',annot=True)
# sales와 salary는 object형 변수임으로 계산이 안된다.

# %%
sns.lmplot(x='satisfaction_level', y='left', hue='sales', data=df, fit_reg=False)

# %%
df['sales'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
# df['position']=df['sales'].replace({:[1:11]})

# %%
position= [i for i in range(101)] #np.array([])
pd.merge(position,df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-86576be8c8fc> in <module>
#       1 position= [i for i in range(101)] #np.array([])
# ----> 2 pd.merge(position,df)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
df['position']=df['sales'].astype('category')
df['position'].cat.categories
# Out:
# Index(['IT', 'RandD', 'accounting', 'hr', 'management', 'marketing',
#        'product_mng', 'sales', 'support', 'technical'],
#       dtype='object')

# %%
from mpl_toolkits.mplot3d import Axes3D
#방수, 면적, 집크기 => 시각화(3차원)
fig=plt.figure(figsize=(12,8))
ax=fig.add_subplot(1,1,1, projection="3d")
ax.scatter(df['satisfaction_level'], df['left'], 
           df['sales'], c='green', alpha=.5)
ax.set(xlabel='satisfaction_level', ylabel='left', zlabel='Work_accident')
ax.set(ylim=[0,250000])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-06ec88714dd7> in <module>
#       4 ax=fig.add_subplot(1,1,1, projection="3d")
#       5 ax.scatter(df['satisfaction_level'], df['left'],
# ----> 6            df['sales'], c='green', alpha=.5)
#       7 ax.set(xlabel='satisfaction_level', ylabel='left', zlabel='Work_accident')
#       8 ax.set(ylim=[0,250000])
#
# ~\AppData\Roaming\Python\Python37\site-packages\mpl_toolkits\mplot3d\axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2356             self.set_zmargin(0.05)
#    2357
# -> 2358         self.auto_scale_xyz(xs, ys, zs, had_data)
#    2359
#    2360         return patches
#
# ~\AppData\Roaming\Python\Python37\site-packages\mpl_toolkits\mplot3d\axes3d.py in auto_scale_xyz(self, X, Y, Z, had_data)
#     500             Z = np.reshape(Z, -1)
# ...
